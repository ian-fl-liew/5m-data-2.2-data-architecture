# %% [markdown]
# ### Conda Environment Setup

# %%
cd /home/seanl/NTU/DSAI/5m-data-2.1-intro-big-data-eng/environments/python_3_11

# bde
conda env create --file bde-environment.yml

# elt
conda env create --file elt-environment.yml

# dagster
conda env create --file dagster-environment.yml

# kafka
conda env create --file kafka-environment.yml

# ooc
conda env create --file ooc-environment.yml

# %% [markdown]
# ### Redis Connection

# %%
"""Basic connection example.
"""

import redis

r = redis.Redis(
    host='bushes-fall-fowl-95873.db.redis.io',
    port=18992,
    decode_responses=True,
    username="default",
    password="U0kUL6qo7OFXCK1VDTlXfUpBtFlRs5Cg",
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar

# %% [markdown]
# ### GCP
# GCP Project ID: pacific-smile-403809
#
# ### gCloud CLI
#
# 1. curl https://sdk.cloud.google.com | bash
# 2. exec -l $SHELL
# 3. gcloud init
#
#
# ### After Init
# Setup Trust to GCP Project
#
# ### Enable BigQuery API in CLI
# gcloud services enable bigquery.googleapis.com --project=ntu-bigdata-project
#
# Sample Query: bq query --use_legacy_sql=false "SELECT name FROM bigquery-public-data.usa_names.usa_1910_current LIMIT 10"

# %% [markdown]
# NotebookLM for Module 2
# 📚 Here is the compiled list of all the notebooks for your convenience. Enjoy! 🤗
#
# 2.1 Introduction to Big Data
# 2.2 Data Architecture
# 2.3 Data Encoding and Data Flow
# 2.4 Data Extraction adn Web Scraping
# 2.5 Data Warehouses
# 2.6 Data Pipelines
# 2.7 Data Orchestration and Testing
# 2.8 Out of Core Processing
# 2.9 Distributed Batch Processing and Transformation
# 2.10 Stream Processing and Analytics
#
# 💡 Although you can't clone the notebooks here, you can try to create your own
# notebooks!
#
# 2.1: Big Data and Data Engineering Fundamentals
# https://notebook.google.com/notebook/0e1eeb1e-3190-4813-a4a4-223a7817fd77
#
# 2.2 Data Architecture
# https://notebook.google.com/notebook/26bc5db5-6259-4d9f-873c-d48e42158a87
#
# 2.3 Data Encoding and Data Flow
# https://notebook.google.com/notebook/321ef992-6e9b-46a6-90dc-f17a6761ff5f
